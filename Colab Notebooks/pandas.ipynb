# %% [markdown]
# Import libraries

# %%
import pandas as pd

# %%
x = [1,2,3,4,5]

# %%
pd.Series(x)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series(x, index=['a','b','c','d','e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data = {'name': ['a', 'b', 'c'], 'marks':[1,2,3]}
df = pd.DataFrame(data)
display(df)
display(data)
# Out:
#   name  marks
# 0    a      1
# 1    b      2
# 2    c      3
# {'name': ['a', 'b', 'c'], 'marks': [1, 2, 3]}

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([6,7,8,9,10])
s1.add(s2)
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %% [markdown]
# 1) read dataset using read_csv
# 2) use .head(), .tail(), .sample()
# 3) display first 3 rows
# 4) convert the 3 rows data to csv file using to_csv()
# 5) create a new column by adding your existing columns
# 6) observe data using isnull(), info(), describe()
# 7) use loc an iloc to filter the rows and columns
# 8) use value_counts()
# 9) use isin() return true or false
# 10) upload a files in Github name repo: numpy and pandas: upload our files with your data, add readme also which explains what have to done(public)

# %% [markdown]
# Read csv file

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset_files/student_dataset.csv')
df
# Out:
#     ID      Name  Marks  Subject Grade
# 0    1      Alex   85.0     Math     A
# 1    2      Emma   78.0  Science     B
# 2    3      Liam   90.0     Math     A
# 3    4    Sophia   65.0  English     C
# 4    5      Noah   88.0  Science     A
# 5    6       Mia   72.0     Math     B
# 6    7     James   60.0  English     C
# 7    8    Olivia   95.0  Science     A
# 8    9     Ethan    NaN     Math     B
# 9   10     Emily   70.0  English     B
# 10  11      Alex   85.0     Math     A
# 11  12      Emma   78.0  Science     B
# 12  13     Lucas   55.0     Math     C
# 13  14    Amelia   92.0  Science     A
# 14  15    Daniel   68.0  English     C
# 15  16     Grace   75.0     Math     B
# 16  17  Benjamin   80.0  Science     B
# 17  18     Chloe    NaN  English     B
# 18  19     Ethan   66.0     Math     B
# 19  20  Isabella   89.0  Science     A

# %%
display(df.head())
display(df.tail())
display(df.sample())
# Out:
#    ID    Name  Marks  Subject Grade
# 0   1    Alex   85.0     Math     A
# 1   2    Emma   78.0  Science     B
# 2   3    Liam   90.0     Math     A
# 3   4  Sophia   65.0  English     C
# 4   5    Noah   88.0  Science     A
#     ID      Name  Marks  Subject Grade
# 15  16     Grace   75.0     Math     B
# 16  17  Benjamin   80.0  Science     B
# 17  18     Chloe    NaN  English     B
# 18  19     Ethan   66.0     Math     B
# 19  20  Isabella   89.0  Science     A
#     ID    Name  Marks  Subject Grade
# 13  14  Amelia   92.0  Science     A

# %%
display(df.head(3))
# Out:
#    ID  Name  Marks  Subject Grade
# 0   1  Alex   85.0     Math     A
# 1   2  Emma   78.0  Science     B
# 2   3  Liam   90.0     Math     A

# %%
three_rows = df.head(3)
three_rows.to_csv('first_3_rows.csv', index=False)
print("First 3 rows saved to 'first_3_rows.csv'")
# Out:
# First 3 rows saved to 'first_3_rows.csv'

# %%
df['Total_Score'] = df['ID'] + df['Marks']
display(df.head())
# Out:
#    ID    Name  Marks  Subject Grade  Total_Score
# 0   1    Alex   85.0     Math     A         86.0
# 1   2    Emma   78.0  Science     B         80.0
# 2   3    Liam   90.0     Math     A         93.0
# 3   4  Sophia   65.0  English     C         69.0
# 4   5    Noah   88.0  Science     A         93.0

# %%
display(df.isnull())
display(df.info())
display(df.describe())
# Out:
#        ID   Name  Marks  Subject  Grade  Total_Score
# 0   False  False  False    False  False        False
# 1   False  False  False    False  False        False
# 2   False  False  False    False  False        False
# 3   False  False  False    False  False        False
# 4   False  False  False    False  False        False
# 5   False  False  False    False  False        False
# 6   False  False  False    False  False        False
# 7   False  False  False    False  False        False
# 8   False  False   True    False  False         True
# 9   False  False  False    False  False        False
# 10  False  False  False    False  False        False
# 11  False  False  False    False  False        False
# 12  False  False  False    False  False        False
# 13  False  False  False    False  False        False
# 14  False  False  False    False  False        False
# 15  False  False  False    False  False        False
# 16  False  False  False    False  False        False
# ...

# %% [markdown]
# Using loc to get specified data

# %%
display(df.loc[0])
# Out:
# ID                1
# Name           Alex
# Marks          85.0
# Subject        Math
# Grade             A
# Total_Score    86.0
# Name: 0, dtype: object

# %%
display(df.loc[[0, 1, 2]])
# Out:
#    ID  Name  Marks  Subject Grade  Total_Score
# 0   1  Alex   85.0     Math     A         86.0
# 1   2  Emma   78.0  Science     B         80.0
# 2   3  Liam   90.0     Math     A         93.0

# %%
display(df.loc[0:4, ['Name', 'Marks']])
# Out:
#      Name  Marks
# 0    Alex   85.0
# 1    Emma   78.0
# 2    Liam   90.0
# 3  Sophia   65.0
# 4    Noah   88.0

# %%
display(df.iloc[0])
# Out:
# ID                1
# Name           Alex
# Marks          85.0
# Subject        Math
# Grade             A
# Total_Score    86.0
# Name: 0, dtype: object

# %%
display(df.iloc[0:3])
# Out:
#    ID  Name  Marks  Subject Grade  Total_Score
# 0   1  Alex   85.0     Math     A         86.0
# 1   2  Emma   78.0  Science     B         80.0
# 2   3  Liam   90.0     Math     A         93.0

# %% [markdown]
# ### Picking Both Rows and Columns by Position

# %%
print("Selecting first 5 rows and first 3 columns")
display(df.iloc[0:5, 0:3]) # 0:5 for rows (0,1,2,3,4), 0:3 for columns (0,1,2)
# Out:
# Selecting first 5 rows and first 3 columns
#    ID    Name  Marks
# 0   1    Alex   85.0
# 1   2    Emma   78.0
# 2   3    Liam   90.0
# 3   4  Sophia   65.0
# 4   5    Noah   88.0
